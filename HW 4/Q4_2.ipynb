# %%
losses1 = []
textfile = open("loss1.txt", "r")
for element in textfile:
    losses1.append(float(element))
# print(losses1)
textfile.close()

# %%
losses2 = []
textfile = open("loss2.txt", "r")
for element in textfile:
    losses2.append(float(element))
# print(losses2)
textfile.close()

# %%
losses3 = []
textfile = open("loss3.txt", "r")
for element in textfile:
    losses3.append(float(element))
# print(losses3)
textfile.close()

# %%
losses4 = []
textfile = open("loss4.txt", "r")
for element in textfile:
    losses4.append(float(element))
# print(losses4)
textfile.close()

# %%
losses5 = []
textfile = open("loss5.txt", "r")
for element in textfile:
    losses5.append(float(element))
# print(losses5)
textfile.close()

# %%
import matplotlib.pyplot as plt

plt.plot(range(len(losses1)),losses1)
plt.plot(range(len(losses2)),losses2)
plt.plot(range(len(losses3)),losses3)
plt.plot(range(len(losses4)),losses4)
plt.plot(range(len(losses5)),losses5)
plt.ylim(0,3)
# Out:
# (0.0, 3.0)

# %%
v100 = []

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses1)+1),losses1,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
v100.append(popt)
print(popt)
plt.plot(range(1,len(losses1)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses1)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses1)+1),losses1,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [ 7.01994062e-05  4.87482273e-01 -1.50206444e-01]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses2)+1),losses2,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
v100.append(popt)
print(popt)
plt.plot(range(1,len(losses2)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses2)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses2)+1),losses2,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [ 9.96594588e-05  4.74812073e-01 -1.20806639e-01]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses3)+1),losses3,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
v100.append(popt)
print(popt)
plt.plot(range(1,len(losses3)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses3)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses3)+1),losses3,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [ 1.32378100e-04  4.69869572e-01 -9.88729486e-02]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses4)+1),losses4,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
v100.append(popt)
print(popt)
plt.plot(range(1,len(losses4)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses4)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses4)+1),losses4,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [ 1.72993949e-04  4.67240070e-01 -8.18453202e-02]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses5)+1),losses5,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
v100.append(popt)
print(popt)
plt.plot(range(1,len(losses5)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses5)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses5)+1),losses5,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [ 1.63617982e-04  4.65227282e-01 -8.58001223e-02]

# %%
print(v100)
# Out:
# [array([ 7.01994062e-05,  4.87482273e-01, -1.50206444e-01]), array([ 9.96594588e-05,  4.74812073e-01, -1.20806639e-01]), array([ 1.32378100e-04,  4.69869572e-01, -9.88729486e-02]), array([ 1.72993949e-04,  4.67240070e-01, -8.18453202e-02]), array([ 1.63617982e-04,  4.65227282e-01, -8.58001223e-02])]

# %%
import pandas as pd

loss_data = pd.read_pickle('merged_result_P100.pickle')

# %%
loss = []
for i in loss_data:
    if i!='resnet50':
        loss.append(loss_data[i])
loss.append(loss_data['resnet50'])

# %%
p100 = []
losses1,losses2,losses3,losses4,losses5,_= loss

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses1)+1),losses1,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
p100.append(popt)
print(popt)
plt.plot(range(1,len(losses1)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses1)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses1)+1),losses1,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [1.98766092e-04 5.48874855e-01 1.76083898e-02]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses2)+1),losses2,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
p100.append(popt)
print(popt)
plt.plot(range(1,len(losses2)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses2)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses2)+1),losses2,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [2.90696922e-04 5.69169631e-01 5.44017628e-02]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses3)+1),losses3,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
p100.append(popt)
print(popt)
plt.plot(range(1,len(losses3)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses3)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses3)+1),losses3,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [3.15287961e-04 5.30339862e-01 2.07627717e-02]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses4)+1),losses4,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
p100.append(popt)
print(popt)
plt.plot(range(1,len(losses4)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses4)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses4)+1),losses4,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [3.57152914e-04 4.70425416e-01 1.78155181e-02]

# %%
from scipy.optimize import curve_fit
def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses5)+1),losses5,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
p100.append(popt)
print(popt)
plt.plot(range(1,len(losses5)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses5)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses5)+1),losses5,alpha=0.3,label='Loss curve')
plt.legend()
# Out:
# [3.68076907e-04 4.27519868e-01 8.02674203e-03]

# %%
print(v100)
print(p100)
# Out:
# [array([ 7.01994062e-05,  4.87482273e-01, -1.50206444e-01]), array([ 9.96594588e-05,  4.74812073e-01, -1.20806639e-01]), array([ 1.32378100e-04,  4.69869572e-01, -9.88729486e-02]), array([ 1.72993949e-04,  4.67240070e-01, -8.18453202e-02]), array([ 1.63617982e-04,  4.65227282e-01, -8.58001223e-02])]
# [array([1.98766092e-04, 5.48874855e-01, 1.76083898e-02]), array([2.90696922e-04, 5.69169631e-01, 5.44017628e-02]), array([3.15287961e-04, 5.30339862e-01, 2.07627717e-02]), array([3.57152914e-04, 4.70425416e-01, 1.78155181e-02]), array([3.68076907e-04, 4.27519868e-01, 8.02674203e-03])]

# %%
# k80
import numpy as np

losses1 = np.load('resnet18_losses.npz')
losses2 = np.load('resnet20_losses.npz')
losses3 = np.load('resnet32_losses.npz')
losses4 = np.load('resnet44_losses.npz')
losses5 = np.load('resnet56_losses.npz')
losses1 = losses1.f.arr_0
losses2 = losses2.f.arr_0
losses3 = losses3.f.arr_0
losses4 = losses4.f.arr_0
losses5 = losses5.f.arr_0
# print(losses1.keys)
k80 = []

losses6 = np.load('resnet50_new.npz')
losses6 = losses6.f.a
print(losses6)
# Out:
# [7.00012493e+00 6.51588106e+00 6.20615292e+00 ... 4.14951630e-02
#  3.50350663e-02 4.87744343e-03]

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses1)+1),losses1,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
k80.append(popt)
print(popt)
plt.plot(range(1,len(losses1)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses1)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses1)+1),losses1,alpha=0.5,label='Loss curve')
plt.legend()
# Out:
# [ 7.25235662e-05  5.05014458e-01 -1.48671083e-01]

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses2)+1),losses2,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
k80.append(popt)
print(popt)
plt.plot(range(1,len(losses2)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses2)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses2)+1),losses2,alpha=0.5,label='Loss curve')
plt.legend()
# Out:
# [ 1.03425344e-04  4.81340265e-01 -1.18030695e-01]

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses3)+1),losses3,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
k80.append(popt)
print(popt)
plt.plot(range(1,len(losses3)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses3)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses3)+1),losses3,alpha=0.5,label='Loss curve')
plt.legend()
# Out:
# [ 1.46424549e-04  4.71928719e-01 -9.19557722e-02]

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses4)+1),losses4,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
k80.append(popt)
print(popt)
plt.plot(range(1,len(losses4)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses4)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses4)+1),losses4,alpha=0.5,label='Loss curve')
plt.legend()
# Out:
# [ 1.56356261e-04  4.71935887e-01 -8.90760333e-02]

# %%
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

def func(k,beta0,beta1,beta2):
    return (1/(beta0*k+beta1)) + beta2
popt, pcov = curve_fit(func, range(1,len(losses5)+1),losses5,p0=[0.001, 0.1, 1])
beta0,beta1,beta2 = popt
k80.append(popt)
print(popt)
plt.plot(range(1,len(losses5)+1),[func(k,beta0,beta1,beta2) for k in range(1,len(losses5)+1)],label='Predicted loss curve')
plt.plot(range(1,len(losses5)+1),losses5,alpha=0.5,label='Loss curve')
plt.legend()
# Out:
# [ 1.55769825e-04  4.69468259e-01 -8.89310787e-02]

# %%
l_k80 = np.array([[18],[20],[32],[44],[56]])
l_p100 = np.array([[18],[20],[32],[44],[56]])
l_v100 = np.array([[18],[20],[32],[44],[56]])

# %%
b0_k80 = [i[0] for i in k80]
b1_k80 = [i[1] for i in k80]
b2_k80 = [i[2] for i in k80]

b0_p100 = [i[0] for i in p100]
b1_p100 = [i[1] for i in p100]
b2_p100 = [i[2] for i in p100]

b0_v100 = [i[0] for i in v100]
b1_v100 = [i[1] for i in v100]
b2_v100 = [i[2] for i in v100]

# %%
# k80
from sklearn.linear_model import LinearRegression as lr

x = [[i] for i in range(61)]

kb0 = lr().fit(l_k80,b0_k80)
y = kb0.predict(x)
plt.plot(x,y)
plt.scatter(l_k80,b0_k80)
plt.title('beta 0')
plt.show()

kb1 = lr().fit(l_k80,b1_k80)
y = kb1.predict(x)
plt.plot(x,y)
plt.scatter(l_k80,b1_k80)
plt.title('beta 1')
plt.show()

kb2 = lr().fit(l_k80,b2_k80)
y = kb2.predict(x)
plt.plot(x,y)
plt.scatter(l_k80,b2_k80)
plt.title('beta 2')
plt.show()

# %%
# p100
from sklearn.linear_model import LinearRegression as lr

x = [[i] for i in range(61)]

pb0 = lr().fit(l_p100,b0_p100)
y = pb0.predict(x)
plt.plot(x,y)
plt.scatter(l_p100,b0_p100)
plt.title('beta 0')
plt.show()

pb1 = lr().fit(l_p100,b1_p100)
y = pb1.predict(x)
plt.plot(x,y)
plt.scatter(l_p100,b1_p100)
plt.title('beta 1')
plt.show()

pb2 = lr().fit(l_p100,b2_p100)
y = pb2.predict(x)
plt.plot(x,y)
plt.scatter(l_p100,b2_p100)
plt.title('beta 2')
plt.show()

# %%
# v100
from sklearn.linear_model import LinearRegression as lr

x = [[i] for i in range(61)]


vb0 = lr().fit(l_v100,b0_v100)
y = vb0.predict(x)
plt.plot(x,y)
plt.scatter(l_v100,b0_v100)
plt.title('beta 0')
plt.show()

vb1 = lr().fit(l_v100,b1_v100)
y = vb1.predict(x)
plt.plot(x,y)
plt.scatter(l_v100,b1_v100)
plt.title('beta 1')
plt.show()

vb2 = lr().fit(l_v100,b2_v100)
y = vb2.predict(x)
plt.plot(x,y)
plt.scatter(l_v100,b2_v100)
plt.title('beta 2')
plt.show()

# %%
# Predictions for ResNet50
k80beta = [kb0.predict([[50]]),kb1.predict([[50]]),kb2.predict([[50]])]
p100beta = [pb0.predict([[50]]),pb1.predict([[50]]),pb2.predict([[50]])]
v100beta = [vb0.predict([[50]]),vb1.predict([[50]]),vb2.predict([[50]])]
print(k80beta)
print(p100beta)
print(v100beta)
# Out:
# [array([0.00015904]), array([0.46893456]), array([-0.08628932])]
# [array([0.00036428]), array([0.45232191]), array([0.0124901])]
# [array([0.00016694]), array([0.46555051]), array([-0.08310189])]

# %%
losses6 = []
textfile = open("loss6.txt", "r")
for element in textfile:
    losses6.append(float(element))
textfile.close()

# %%
# v100

l = []
err = []
epochs = len(losses6)
for i in range(epochs):
    temp = func(i+1,v100beta[0],v100beta[1],v100beta[2])
    l.append(temp)
    err.append((temp-losses6[i])/losses6[i])
plt.plot([i+1 for i in range(epochs)],losses6,alpha=0.7,color='orange',label='Observed Loss for V100')
plt.plot([i+1 for i in range(epochs)],l,label='Predicted Loss for V100')
plt.legend()
# Percentage error

# %%
def finv(l,b0,b1,b2):
    return ((1/(l-b2))-b1)/b0
# For V100 loss at 92% accuracy = 0.27
print(finv(0.27,v100beta[0],v100beta[1],v100beta[2]),' iterations')
print('Which is equal to ',finv(0.27,v100beta[0],v100beta[1],v100beta[2])//391, ' epochs')
# Out:
# [14175.33011273]  iterantions
# Which is equal to  [36.]  epochs

# %% [markdown]
# As calculated the model reaches 92% accuracy after epoch 36. Percentage error = 0%

# %%
losses6 = loss_data['resnet50']

# %%
# p100

l = []
err = []
epochs = len(losses6)
for i in range(epochs):
    temp = func((i+1),p100beta[0],p100beta[1],p100beta[2])
    l.append(temp)
    err.append((temp-losses6[i])/losses6[i])
plt.plot([i+1 for i in range(epochs)],losses6,alpha=0.7,color='orange',label='Observed Loss for P100')
plt.plot([i+1 for i in range(epochs)],l,label='Predicted Loss for P100')
plt.legend()
# Percentage error

# %%
def finv(l,b0,b1,b2):
    return ((1/(l-b2))-b1)/b0
# For P100 loss at 92% accuracy = 0.18
print(finv(0.18,p100beta[0],p100beta[1],p100beta[2]),' iterations')
print('Which is equal to ',finv(0.18,p100beta[0],p100beta[1],p100beta[2])//391, ' epochs')
# Out:
# [15146.13008173]  iterations
# Which is equal to  [38.]  epochs

# %%
losses6 = np.load('resnet50_new.npz')
losses6 = losses6.f.a

# %%
# k80

l = []
err = []
epochs = len(losses6)
for i in range(epochs):
    temp = func((i+1),k80beta[0],k80beta[1],k80beta[2])
    l.append(temp)
    err.append((temp-losses6[i])/losses6[i])
plt.plot([i+1 for i in range(epochs)],losses6[:epochs],alpha=0.7,color='orange',label='Observed Loss for K80')
plt.plot([i+1 for i in range(epochs)],l,label='Predicted Loss for K80')
plt.legend()
# Percentage error

# %%
def finv(l,b0,b1,b2):
    return ((1/(l-b2))-b1)/b0
# For P100 loss at 92% accuracy = 0.23
print(finv(0.23,k80beta[0],k80beta[1],k80beta[2]),' iterations')
print('Which is equal to ',finv(0.23,k80beta[0],k80beta[1],k80beta[2])//391, ' epochs')
# Out:
# [16930.7875504]  iterations
# Which is equal to  [43.]  epochs

# %% [markdown]
# 92% occurs at 36 epochs. error = 19.4%

# %%
def f(p,w):
    return (1.02*(128/w) + 2.78 + 4.92*w/p + 0*w + 0.02*p)**-1

# %%
import matplotlib.pyplot as plt

w = range(1,51)
# 92% occurs at epoch 36
epoch = 36
plt.plot(w,[epoch/f(2,w[i]) for i in range(50)],label='2 Parameter Servers')
plt.plot(w,[epoch/f(4,w[i]) for i in range(50)],label='4 Parameter Servers')
plt.xlabel('no of workers')
plt.ylabel('time')
plt.legend()
